# %%
import pandas as pd
data0 = pd.read_csv('data_preprocessing_0.csv')
data1 = pd.read_csv('data_preprocessing_1.csv')
data2 = pd.read_csv('data_preprocessing_2.csv')
data3 = pd.read_csv('data_preprocessing_3.csv')
data4 = pd.read_csv('data_preprocessing_4.csv')
data5 = pd.read_csv('data_preprocessing_5.csv')
data6 = pd.read_csv('data_preprocessing_6.csv')
data7 = pd.read_csv('data_preprocessing_7.csv')
data8 = pd.read_csv('data_preprocessing_8.csv')
data9 = pd.read_csv('data_preprocessing_9.csv')

# %%
data_var = pd.read_csv('lf_card_corona_temp2.csv')

# %%
data_var = data_var.drop(['Unnamed: 0'], axis=1)

# %%
data_var
# Out:
#       emd_nm  emd_cluster  long_cluster year_month  method_x  tot_pop_cnt  \
# 0        삼양동            3             1    2018-01      diff    1086.5580
# 1        삼양동            3             1    2018-01      diff    1086.5580
# 2        삼양동            3             1    2018-01      diff    1086.5580
# 3        삼양동            3             2    2018-01      diff    7299.3206
# 4        삼양동            3             2    2018-01      diff    7299.3206
# ...      ...          ...           ...        ...       ...          ...
# 16006   일도1동            7             2    2021-06      diff   33015.7726
# 16007   일도1동            7             2    2021-06      diff   33015.7726
# 16008   일도1동            7             3    2021-06  log_diff    1499.2836
# 16009   일도1동            7             3    2021-06  log_diff    1499.2836
# 16010   일도1동            7             3    2021-06  log_diff    1499.2836
#
#        tot_pop_cnt2  card_cluster     use_amt  method_y      use_amt2  corona  \
# ...

# %%
data_var = data_var.sort_values(['emd_cluster', 'long_cluster', 'emd_nm', 'year_month']).reset_index(drop=True)

# %%
data_pop = data_var[['emd_nm', 'emd_cluster', 'year_month', 'long_cluster', 'year_month', 'tot_pop_cnt2']]
data_card = data_var[['emd_nm', 'emd_cluster', 'year_month', 'card_cluster', 'use_amt2']]
data_corona_avg = data_var[['emd_nm', 'emd_cluster', 'year_month', 'corona', 'avg_temp']]

# %%
data_pop = data_pop.drop_duplicates().reset_index(drop=True)
data_card = data_card.drop_duplicates().reset_index(drop=True)
data_corona_avg = data_corona_avg.drop_duplicates().reset_index(drop=True)

# %%
data_pop_1 = data_pop[data_pop['emd_cluster'] == 1]
data_pop_2 = data_pop[data_pop['emd_cluster'] == 2]
data_pop_3 = data_pop[data_pop['emd_cluster'] == 3]
data_pop_4 = data_pop[data_pop['emd_cluster'] == 4]
data_pop_5 = data_pop[data_pop['emd_cluster'] == 5]
data_pop_6 = data_pop[data_pop['emd_cluster'] == 6]
data_pop_7 = data_pop[data_pop['emd_cluster'] == 7]
data_pop_8 = data_pop[data_pop['emd_cluster'] == 8]
data_pop_9 = data_pop[data_pop['emd_cluster'] == 9]

# %%
data_pop_1[data_pop_1['long_cluster'] == 3]
# Out:
#     emd_nm  emd_cluster year_month  long_cluster year_month  tot_pop_cnt2
# 588   삼도1동            1    2018-01             3    2018-01           NaN
# 589   삼도1동            1    2018-02             3    2018-02           NaN
# 590   삼도1동            1    2018-03             3    2018-03      319.0533
# 591   삼도1동            1    2018-04             3    2018-04     2515.5637
# 592   삼도1동            1    2018-05             3    2018-05     2666.2403
# ..     ...          ...        ...           ...        ...           ...
# 877    화북동            1    2021-02             3    2021-02    -3343.2242
# 878    화북동            1    2021-03             3    2021-03    -3983.3369
# 879    화북동            1    2021-04             3    2021-04     3208.1451
# 880    화북동            1    2021-05             3    2021-05     -370.8805
# 881    화북동            1    2021-06             3    2021-06     1566.5488
#
# [294 rows x 6 columns]

# %%
for i in range(1,10):
    exec("temp = data_pop_" + str(i))
    for j in set(temp['long_cluster']):
        temp_1 = temp[temp['long_cluster'] == j].reset_index(drop=True)
        exec("data" + str(i) + "['lf-" + str(j) + "'] = temp_1['tot_pop_cnt2']")

# %%
data_card_1 = data_card[data_card['emd_cluster'] == 1]
data_card_2 = data_card[data_card['emd_cluster'] == 2]
data_card_3 = data_card[data_card['emd_cluster'] == 3]
data_card_4 = data_card[data_card['emd_cluster'] == 4]
data_card_5 = data_card[data_card['emd_cluster'] == 5]
data_card_6 = data_card[data_card['emd_cluster'] == 6]
data_card_7 = data_card[data_card['emd_cluster'] == 7]
data_card_8 = data_card[data_card['emd_cluster'] == 8]
data_card_9 = data_card[data_card['emd_cluster'] == 9]

# %%
data_card_1
# Out:
#     emd_nm  emd_cluster year_month  card_cluster      use_amt2
# 0     삼도1동            1    2018-01             1           NaN
# 1     삼도1동            1    2018-01             2           NaN
# 2     삼도1동            1    2018-01             3           NaN
# 3     삼도1동            1    2018-02             1           NaN
# 4     삼도1동            1    2018-02             2  2.095025e+01
# ..     ...          ...        ...           ...           ...
# 877    화북동            1    2021-05             2  2.137039e+01
# 878    화북동            1    2021-05             3  3.852918e+07
# 879    화북동            1    2021-06             1  8.309337e-02
# 880    화북동            1    2021-06             2  2.140199e+01
# 881    화북동            1    2021-06             3  1.012565e+08
#
# [882 rows x 5 columns]

# %%
for i in range(1,10):
    exec("temp = data_card_" + str(i))
    for j in set(temp['card_cluster']):
        temp_1 = temp[temp['card_cluster'] == j].reset_index(drop=True)
        exec("data" + str(i) + "['card-" + str(j) + "'] = temp_1['use_amt2']")

# %%
for i in range(1,10):
    exec("temp = data_corona_avg[data_corona_avg['emd_cluster']==" + str(i) + "]")
    temp = temp.reset_index(drop=True)
    exec("data" + str(i) + "['corona'] = temp['corona']")
    exec("data" + str(i) + "['avg_temp'] = temp['avg_temp']")

# %%
import statsmodels.api as sm

# %%
data1 = data1.dropna().reset_index()
data2 = data2.dropna().reset_index()
data3 = data3.dropna().reset_index()
data4 = data4.dropna().reset_index()
data5 = data5.dropna().reset_index()
data6 = data6.dropna().reset_index()
data7 = data7.dropna().reset_index()
data8 = data8.dropna().reset_index()
data9 = data9.dropna().reset_index()

# %%
data1
# Out:
#      index  Unnamed: 0  cluster emd_nm year_month        em_g   r-1-1-2  \
# 0        2           2        1   삼도1동    2018-03   5123750.0 -0.040580
# 1        3           3        1   삼도1동    2018-04  -6673250.0 -0.361701
# 2        4           4        1   삼도1동    2018-05   1184600.0 -0.070241
# 3        5           5        1   삼도1동    2018-06   4865250.0  0.080212
# 4        6           6        1   삼도1동    2018-07  15077600.0  0.046551
# ..     ...         ...      ...    ...        ...         ...       ...
# 235    247         247        1    화북동    2021-02 -27130700.0  0.035305
# 236    248         248        1    화북동    2021-03  22597450.0 -0.143738
# 237    249         249        1    화북동    2021-04  -2026800.0 -0.021645
# 238    250         250        1    화북동    2021-05   9679900.0 -0.061175
# 239    251         251        1    화북동    2021-06   1433250.0  0.105152
#
#        r-1-2-1   r-1-2-2     w-1-1-1  ...   v-1-2-1      v-1-2-2        lf-1  \
# ...

# %%
data1_X = data1.drop(['index', 'cluster', 'Unnamed: 0', 'emd_nm', 'year_month', 'em_g'], axis=1)
data1_y = data1['em_g']
data2_X = data2.drop(['index', 'cluster', 'Unnamed: 0', 'emd_nm', 'year_month', 'em_g'], axis=1)
data2_y = data2['em_g']
data3_X = data3.drop(['index', 'cluster', 'Unnamed: 0', 'emd_nm', 'year_month', 'em_g'], axis=1)
data3_y = data3['em_g']
data4_X = data4.drop(['index', 'cluster', 'Unnamed: 0', 'emd_nm', 'year_month', 'em_g'], axis=1)
data4_y = data4['em_g']
data5_X = data5.drop(['index', 'cluster', 'Unnamed: 0', 'emd_nm', 'year_month', 'em_g'], axis=1)
data5_y = data5['em_g']
data6_X = data6.drop(['index', 'cluster', 'Unnamed: 0', 'emd_nm', 'year_month', 'em_g'], axis=1)
data6_y = data6['em_g']
data7_X = data7.drop(['index', 'cluster', 'Unnamed: 0', 'emd_nm', 'year_month', 'em_g'], axis=1)
data7_y = data7['em_g']
data8_X = data8.drop(['index', 'cluster', 'Unnamed: 0', 'emd_nm', 'year_month', 'em_g'], axis=1)
data8_y = data8['em_g']
data9_X = data9.drop(['index', 'cluster', 'Unnamed: 0', 'emd_nm', 'year_month', 'em_g'], axis=1)
data9_y = data9['em_g']

# %%
data1_X  = sm.add_constant(data1_X, has_constant = "add")
data2_X  = sm.add_constant(data2_X, has_constant = "add")
data3_X  = sm.add_constant(data3_X, has_constant = "add")
data4_X  = sm.add_constant(data4_X, has_constant = "add")
data5_X  = sm.add_constant(data5_X, has_constant = "add")
data6_X  = sm.add_constant(data6_X, has_constant = "add")
data7_X  = sm.add_constant(data7_X, has_constant = "add")
data8_X  = sm.add_constant(data8_X, has_constant = "add")
data9_X  = sm.add_constant(data9_X, has_constant = "add")

# %%
n=1
import statsmodels.api as sm
for i in set(data1['emd_nm']):
    data1_temp = data1[data1['emd_nm'] == i]
    data1_X = data1_temp.drop(['index','cluster', 'Unnamed: 0', 'emd_nm', 'year_month', 'em_g'], axis=1)
    data1_y = data1_temp['em_g']
    data1_X = sm.add_constant(data1, has_constant = 'add')
    exec("model_"+str(n) + "= Lasso()")
    exec("model_"+str(n) + "= model_" + str(n) + ".fit(data1_X,data1_y)")
    print(i)
    exec("print(model_" + str(n) + ".score(data1_X, data1_y))")
    n+=1
# Out:
# 0.5181000405355496
# 0.6020945671023219
# 0.6753193353851827
# 0.5842131792520943
# 0.6566603867776848
# 0.5869610231649247

# %%
n=1
import statsmodels.api as sm
for i in set(data1['emd_nm']):
    data1_temp = data1[data1['emd_nm'] == i]
    data1_X = data1_temp.drop(['index','cluster', 'Unnamed: 0', 'emd_nm', 'year_month', 'em_g'], axis=1)
    data1_y = data1_temp['em_g']
    data1_X = sm.add_constant(data1_X, has_constant = 'add')
    model = sm.OLS(data1_y, data1_X)
    fitted_model = model.fit()
    print(i)
    print(fitted_model.summary())
# Out:
# 삼도1동
#                             OLS Regression Results
# ...
# Dep. Variable:                   em_g   R-squared:                       0.518
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     1.021
# Date:                Tue, 14 Sep 2021   Prob (F-statistic):              0.483
# Time:                        19:44:08   Log-Likelihood:                -669.93
# No. Observations:                  40   AIC:                             1382.
# Df Residuals:                      19   BIC:                             1417.
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.614e+07   9.49e+08     -0.017      0.987      -2e+09    1.97e+09
# ...

# %%
n=1
import statsmodels.api as sm
for i in set(data2['emd_nm']):
    data1_temp = data2[data2['emd_nm'] == i]
    data1_X = data1_temp.drop(['index','cluster', 'Unnamed: 0', 'emd_nm', 'year_month', 'em_g'], axis=1)
    data1_y = data1_temp['em_g']
    data1_X = sm.add_constant(data1_X, has_constant = 'add')
    model = sm.OLS(data1_y, data1_X)
    fitted_model = model.fit()
    print(i)
    print(fitted_model.summary())
# Out:
# 이도2동
#                             OLS Regression Results
# ...
# Dep. Variable:                   em_g   R-squared:                       0.780
# Model:                            OLS   Adj. R-squared:                  0.427
# Method:                 Least Squares   F-statistic:                     2.213
# Date:                Tue, 14 Sep 2021   Prob (F-statistic):             0.0570
# Time:                        19:44:44   Log-Likelihood:                -702.89
# No. Observations:                  40   AIC:                             1456.
# Df Residuals:                      15   BIC:                             1498.
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.654e+09   2.78e+09      0.954      0.355   -3.28e+09    8.58e+09
# ...

# %%
n=1
import statsmodels.api as sm
for i in set(data3['emd_nm']):
    data1_temp = data3[data3['emd_nm'] == i]
    data1_X = data1_temp.drop(['index','cluster', 'Unnamed: 0', 'emd_nm', 'year_month', 'em_g'], axis=1)
    data1_y = data1_temp['em_g']
    data1_X = sm.add_constant(data1_X, has_constant = 'add')
    model = sm.OLS(data1_y, data1_X)
    fitted_model = model.fit()
    print(i)
    print(fitted_model.summary())
# Out:
# 아라동
#                             OLS Regression Results
# ...
# Dep. Variable:                   em_g   R-squared:                       0.482
# Model:                            OLS   Adj. R-squared:                 -0.063
# Method:                 Least Squares   F-statistic:                    0.8847
# Date:                Tue, 14 Sep 2021   Prob (F-statistic):              0.607
# Time:                        19:45:01   Log-Likelihood:                -696.95
# No. Observations:                  40   AIC:                             1436.
# Df Residuals:                      19   BIC:                             1471.
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.589e+08   1.45e+09      0.455      0.654   -2.37e+09    3.69e+09
# ...

# %%
n=1
import statsmodels.api as sm
for i in set(data4['emd_nm']):
    data1_temp = data4[data4['emd_nm'] == i]
    data1_X = data1_temp.drop(['index','cluster', 'Unnamed: 0', 'emd_nm', 'year_month', 'em_g'], axis=1)
    data1_y = data1_temp['em_g']
    data1_X = sm.add_constant(data1_X, has_constant = 'add')
    model = sm.OLS(data1_y, data1_X)
    fitted_model = model.fit()
    print(i)
    print(fitted_model.summary())
# Out:
# 송산동
#                             OLS Regression Results
# ...
# Dep. Variable:                   em_g   R-squared:                       0.575
# Model:                            OLS   Adj. R-squared:                 -0.105
# Method:                 Least Squares   F-statistic:                    0.8454
# Date:                Tue, 14 Sep 2021   Prob (F-statistic):              0.653
# Time:                        19:45:34   Log-Likelihood:                -653.31
# No. Observations:                  40   AIC:                             1357.
# Df Residuals:                      15   BIC:                             1399.
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.229e+07   9.27e+07      0.348      0.732   -1.65e+08     2.3e+08
# ...

# %%
n=1
import statsmodels.api as sm
for i in set(data5['emd_nm']):
    data1_temp = data5[data5['emd_nm'] == i]
    data1_X = data1_temp.drop(['index','cluster', 'Unnamed: 0', 'emd_nm', 'year_month', 'em_g'], axis=1)
    data1_y = data1_temp['em_g']
    data1_X = sm.add_constant(data1_X, has_constant = 'add')
    model = sm.OLS(data1_y, data1_X)
    fitted_model = model.fit()
    print(i)
    print(fitted_model.summary())
# Out:
# 천지동
#                             OLS Regression Results
# ...
# Dep. Variable:                   em_g   R-squared:                       0.522
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     1.034
# Date:                Tue, 14 Sep 2021   Prob (F-statistic):              0.473
# Time:                        19:45:54   Log-Likelihood:                -640.83
# No. Observations:                  38   AIC:                             1322.
# Df Residuals:                      18   BIC:                             1354.
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.854e+08   2.03e+08      0.913      0.373   -2.41e+08    6.12e+08
# ...

# %%
n=1
import statsmodels.api as sm
for i in set(data6['emd_nm']):
    data1_temp = data6[data6['emd_nm'] == i]
    data1_X = data1_temp.drop(['index','cluster', 'Unnamed: 0', 'emd_nm', 'year_month', 'em_g'], axis=1)
    data1_y = data1_temp['em_g']
    data1_X = sm.add_constant(data1_X, has_constant = 'add')
    model = sm.OLS(data1_y, data1_X)
    fitted_model = model.fit()
    print(i)
    print(fitted_model.summary())
# Out:
# 대정읍
#                             OLS Regression Results
# ...
# Dep. Variable:                   em_g   R-squared:                       0.629
# Model:                            OLS   Adj. R-squared:                  0.193
# Method:                 Least Squares   F-statistic:                     1.443
# Date:                Tue, 14 Sep 2021   Prob (F-statistic):              0.225
# Time:                        19:46:13   Log-Likelihood:                -655.15
# No. Observations:                  38   AIC:                             1352.
# Df Residuals:                      17   BIC:                             1387.
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        1.12e+08   2.02e+08      0.554      0.587   -3.14e+08    5.38e+08
# ...

# %%
n=1
import statsmodels.api as sm
for i in set(data7['emd_nm']):
    data1_temp = data7[data7['emd_nm'] == i]
    data1_X = data1_temp.drop(['index','cluster', 'Unnamed: 0', 'emd_nm', 'year_month', 'em_g'], axis=1)
    data1_y = data1_temp['em_g']
    data1_X = sm.add_constant(data1_X, has_constant = 'add')
    model = sm.OLS(data1_y, data1_X)
    fitted_model = model.fit()
    print(i)
    print(fitted_model.summary())
# Out:
# 건입동
#                             OLS Regression Results
# ...
# Dep. Variable:                   em_g   R-squared:                       0.689
# Model:                            OLS   Adj. R-squared:                  0.242
# Method:                 Least Squares   F-statistic:                     1.542
# Date:                Tue, 14 Sep 2021   Prob (F-statistic):              0.188
# Time:                        19:46:25   Log-Likelihood:                -642.30
# No. Observations:                  40   AIC:                             1333.
# Df Residuals:                      16   BIC:                             1373.
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.662e+07   2.94e+08      0.159      0.876   -5.77e+08     6.7e+08
# ...

# %%
n=1
import statsmodels.api as sm
for i in set(data8['emd_nm']):
    data1_temp = data8[data8['emd_nm'] == i]
    data1_X = data1_temp.drop(['index','cluster', 'Unnamed: 0', 'emd_nm', 'year_month', 'em_g'], axis=1)
    data1_y = data1_temp['em_g']
    data1_X = sm.add_constant(data1_X, has_constant = 'add')
    model = sm.OLS(data1_y, data1_X)
    fitted_model = model.fit()
    print(i)
    print(fitted_model.summary())
# Out:
# 표선면
#                             OLS Regression Results
# ...
# Dep. Variable:                   em_g   R-squared:                       0.558
# Model:                            OLS   Adj. R-squared:                 -0.091
# Method:                 Least Squares   F-statistic:                    0.8591
# Date:                Tue, 14 Sep 2021   Prob (F-statistic):              0.636
# Time:                        19:46:43   Log-Likelihood:                -619.20
# No. Observations:                  38   AIC:                             1284.
# Df Residuals:                      15   BIC:                             1322.
# Df Model:                          22
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.671e+08   2.79e+08      1.677      0.114   -1.27e+08    1.06e+09
# ...

# %%
n=1
import statsmodels.api as sm
for i in set(data9['emd_nm']):
    data1_temp = data9[data9['emd_nm'] == i]
    data1_X = data1_temp.drop(['index','cluster', 'Unnamed: 0', 'emd_nm', 'year_month', 'em_g'], axis=1)
    data1_y = data1_temp['em_g']
    data1_X = sm.add_constant(data1_X, has_constant = 'add')
    model = sm.OLS(data1_y, data1_X)
    fitted_model = model.fit()
    print(i)
    print(fitted_model.summary())
# Out:
# 조천읍
#                             OLS Regression Results
# ...
# Dep. Variable:                   em_g   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Tue, 14 Sep 2021   Prob (F-statistic):                nan
# Time:                        19:46:56   Log-Likelihood:                 75.784
# No. Observations:                  19   AIC:                            -113.6
# Df Residuals:                       0   BIC:                            -95.62
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.278e+08        inf          0        nan         nan         nan
# ...
